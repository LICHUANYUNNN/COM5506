# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
G1 = nx.Graph()
G1.add_edges_from([('A','B'),('B','C'),('C','D'),('D','E')])
nx.draw(G1)
# Out:
# D:\Python\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
G2 = nx.Graph()
G2.add_edges_from([('A','B'),('A','C'),('A','D'),('A','E'),('A','F')])
nx.draw(G2)

# %%
G3 = nx.Graph()
G3.add_edges_from([('A','B'),('A','C'),('B','C'),('C','D'),('D','E'),('E','F'),('E','G'),('F','G')])
nx.draw(G3)

# %%
G4 = nx.Graph()
G4.add_edges_from([('A','B'),('B','C'),('B','D'),('C','E'),('D','E')])
nx.draw(G4)
